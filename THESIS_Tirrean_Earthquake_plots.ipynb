# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings

a=pd.read_csv(r"C:\\Users\Ogeid99\Desktop\cataloguess\DATA_no_modify.csv")
a
# Out:
#         #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 0             79  1985-01-02T22:57:43.090000   41.7150    13.9410       5.8
# 1             89  1985-01-03T00:46:16.990000   41.6770    13.9310       6.1
# 2            199  1985-01-04T16:57:40.240000   46.1580     7.1740      10.0
# 3            229  1985-01-04T23:59:54.820000   45.3380     6.6410       5.0
# 4            239  1985-01-05T03:47:03.640000   45.4090     6.6270      10.0
# ...          ...                         ...       ...        ...       ...
# 181772  24334191  2020-04-29T11:17:24.170000   45.9167    12.1917      10.1
# 181773  24335541  2020-04-29T14:14:47.970000   38.4090    13.5617      28.2
# 181774  24336421  2020-04-29T16:23:40.010000   42.8882    13.0363      10.0
# 181775  24336481  2020-04-29T16:30:14.850000   37.7683    14.6293      38.0
# 181776  24337031  2020-04-29T19:21:00.290000   37.8797    12.9638      10.0
#
# ...

# %% [markdown]
# ### Magnitude vs Depth log-scale heatplot

# %%
import matplotlib as mpl
norm = plt.Normalize(0, 5000)
#color = cmap(norm(100.))
bins = np.logspace(np.log10(1),3,num=40)
plt.hist2d(a['Magnitude'],a['Depth/Km'],bins=(43,bins),cmap=plt.cm.RdBu_r,norm=norm)#,norm=mpl.colors.LogNorm())
plt.yscale('log')
plt.colorbar()
plt.ylim(2,200)
plt.xlim(1.5,4)
# Out:
# (1.5, 4)

# %%
fig,axes=plt.subplots(1,1,figsize=(10,6))
sns.scatterplot(a['Magnitude'],a['Depth/Km'],s=15,color='blue')
plt.ylim(0.07,1080)
plt.yscale('log')
plt.gca().invert_yaxis()
plt.ylabel('Depth [km] (log scale)',fontsize=17,labelpad=5)
plt.xlabel('Magnitude',fontsize=17,labelpad=5)
#plt.title('Number of earthquakes greater than 1.5 by depth',fontsize=18,pad=15.0)  
plt.tick_params(labelsize=12)
plt.savefig(r"C:\\Users\Ogeid99\Desktop\tesi\photos_thesis\grafici_finali_jupyter\magnitude_depth_graph.png",bbox_inches='tight',dpi=600)

# %%
condition_a=a[ (a['Depth/Km']>0.1 )&(a['Longitude']<17.01 ) &(a['Longitude']>10.01)&(a['Latitude']<41.01)&(a['Latitude']>38.01) ]
condition_a
condition_a['Boolean']=[1 for i in range(condition_a['Magnitude'].size)]
condition_a
# Out:
# C:\Users\Ogeid99\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 10           489  1985-01-06T17:22:58.540000   39.2910    16.7650       5.0
# 30           989  1985-01-10T15:33:47.400000   39.5280    16.6140      26.4
# 32          1019  1985-01-10T19:29:44.730000   39.6090    16.3710      10.0
# 36          1139  1985-01-12T11:45:09.320000   39.4540    16.6270      22.6
# 37          1159  1985-01-12T17:41:12.700000   39.4500    16.3910      13.3
# ...          ...                         ...       ...        ...       ...
# ...

# %%
a=pd.concat([a,condition_a['Boolean']],axis=1)
a['Boolean']=a['Boolean'].fillna('0')
a
# Out:
#         #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 0             79  1985-01-02T22:57:43.090000   41.7150    13.9410       5.8
# 1             89  1985-01-03T00:46:16.990000   41.6770    13.9310       6.1
# 2            199  1985-01-04T16:57:40.240000   46.1580     7.1740      10.0
# 3            229  1985-01-04T23:59:54.820000   45.3380     6.6410       5.0
# 4            239  1985-01-05T03:47:03.640000   45.4090     6.6270      10.0
# ...          ...                         ...       ...        ...       ...
# 181772  24334191  2020-04-29T11:17:24.170000   45.9167    12.1917      10.1
# 181773  24335541  2020-04-29T14:14:47.970000   38.4090    13.5617      28.2
# 181774  24336421  2020-04-29T16:23:40.010000   42.8882    13.0363      10.0
# 181775  24336481  2020-04-29T16:30:14.850000   37.7683    14.6293      38.0
# 181776  24337031  2020-04-29T19:21:00.290000   37.8797    12.9638      10.0
#
# ...

# %%
fig,axes=plt.subplots(1,1,figsize=(10,6))

sns.scatterplot(a['Magnitude'],a['Depth/Km'],hue=a['Boolean'],s=15,palette=['blue','red'])
plt.ylim(0.07,650)
#plt.yscale('log')
plt.ylabel('Depth [km]',fontsize=17,labelpad=5)
plt.xlabel('Magnitude',fontsize=17,labelpad=5)
plt.gca().invert_yaxis()
#plt.title('Number of earthquakes greater than 1.5 by depth',fontsize=18,pad=15.0)  
plt.tick_params(labelsize=12)
plt.legend().set_visible(False)
plt.savefig(r"C:\\Users\Ogeid99\Desktop\tesi\photos_thesis\grafici_finali_jupyter\magnitude_depth_graph_hue.png",bbox_inches='tight',dpi=600)

# %%
fig,axes=plt.subplots(1,1,figsize=(10,6))
sns.scatterplot(a['Magnitude'],a['Longitude'],s=15,color='blue')
#plt.ylim(0.07,1080)
plt.yscale('log')
plt.gca().invert_yaxis()
plt.ylabel('Depth [km] (log scale)',fontsize=17,labelpad=5)
plt.xlabel('Magnitude',fontsize=17,labelpad=5)
#plt.title('Number of earthquakes greater than 1.5 by depth',fontsize=18,pad=15.0)  
plt.tick_params(labelsize=12)
