# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
a=pd.read_csv("C:\\Users\Ogeid99\Desktop\DS\excel\catalogo_l'aquila.txt",sep='|')
a.sort_values(by='Time',ascending=True) #sort values according to time
num=pd.Series([i for i in range(int(a.size/len(a.columns)))])
a=pd.concat([a,num],axis=1)
#a.set_index(0)
#a.index=[i for i in range(int(a.size/len(a.columns)))]
a
# Out:
#       #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 0      1857689  2008-10-14T02:21:50.850000    42.235     13.515      13.1
# 1      1861549  2008-10-30T02:16:37.440000    42.323     13.491       8.8
# 2      1863429  2008-11-10T01:56:14.140000    42.409     13.539       9.1
# 3      1868139  2008-12-12T18:58:51.600000    42.204     13.387       5.0
# 4      1868339  2008-12-14T08:16:54.180000    42.356     13.467       9.3
# ...        ...                         ...       ...        ...       ...
# 9114   2132989  2009-11-19T16:20:21.220000    42.417     13.387       8.7
# 9115   2132999  2009-11-19T16:21:54.780000    42.410     13.376      10.0
# 9116   2133549  2009-11-20T22:45:50.530000    42.486     13.362      10.8
# 9117   2133719  2009-11-21T08:34:39.570000    42.471     13.356      16.1
# 9118   2133879  2009-11-21T21:34:34.820000    42.299     13.555       8.1
#
#                 Author  Catalog  Contributor  ContributorID MagType  \
# ...

# %%
from datetime import datetime
from math import sin, cos, sqrt, atan2, radians, pow
d=1.6   #it could change... try different values
b=1.5
a_time=pd.Series(a['Time'])
a['Time']=a_time.astype(np.datetime64)
#print(a['Time'])
for j in range(int(a.size/len(a.columns))-9100):  #a.size: size of data frame, a.columns: size of the columns
    #access the first (only) row as a Series using iloc, and then the value using the column name
    timej=a_time.iloc[j]#['Time']   
    latj = radians(a.iloc[j]['Latitude'])
    lonj = radians(a.iloc[j]['Longitude'])
    R = 6373.0    # approximate radius of earth in km
    i=1
    space_time_list=[]
    while i+j <= int(a.size/len(a.columns))-9100 : 
        timei=a_time.iloc[i+j]#['Time']
        dtime=((timei-timej)).total_seconds()
        magnitude=a.iloc[i+j]['Magnitude']
        lati = radians(a.iloc[i+j]['Latitude'])
        loni = radians(a.iloc[i+j]['Longitude'])
        dlon = loni - lonj
        dlat = lati - latj
        a2 = sin(dlat / 2)**2 + cos(latj) * cos(lati) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a2), sqrt(1 - a2))
        distance = R * c
        space_time=dtime*distance**d*pow(10,-b*float(magnitude))
        space_time_list.append(space_time)
        i+=1
    print(space_time_list)
# Out:
# [436041.4101456449, 269165.24563091504, 342400.9574120077, 1441126.2033497074, 5393387.9505117, 907180.4539934287, 145055.68657938432, 619324.4166406199, 3231592.8535758248, 1835785.665810475, 3424371.3300746293, 7301592.454099993, 2581532.6338100615, 2017688.377935095, 3435138.6822348023, 1344949.9160844174, 5558817.336436858, 7821799.631320077, 5562377.442771384]
# [39908.49780656276, 439747.392142928, 152724.81723955032, 1559628.402101334, 161052.85414629363, 55247.032392365436, 247049.30623410468, 1234037.5494980903, 773591.8584391222, 1732653.9148659946, 2824782.8183226027, 1015675.5801306455, 785358.5791983695, 1376173.0901592718, 530794.1657424797, 2176291.9314842653, 2292361.0955041205, 2094166.2345055104]
# ...
