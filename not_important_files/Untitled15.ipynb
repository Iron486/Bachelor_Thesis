# %%
import pandas as pd
DATA=pd.read_csv(r"C:\\Users\Ogeid99\Desktop\cataloguess\DATA.csv")
DATA
# Out:
#         #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 0             79  2005-04-28 20:51:18.989367   41.7150    13.9410       5.8
# 1             89  2005-04-28 19:02:45.089367   41.6770    13.9310       6.1
# 2            199  2005-04-27 02:51:21.839367   46.1580     7.1740      10.0
# 3            229  2005-04-26 19:49:07.259367   45.3380     6.6410       5.0
# 4            239  2005-04-26 16:01:58.439367   45.4090     6.6270      10.0
# ...          ...                         ...       ...        ...       ...
# 181772  24334191  1970-01-02 08:31:37.909367   45.9167    12.1917      10.1
# 181773  24335541  1970-01-02 05:34:14.109367   38.4090    13.5617      28.2
# 181774  24336421  1970-01-02 03:25:22.069367   42.8882    13.0363      10.0
# 181775  24336481  1970-01-02 03:18:47.229367   37.7683    14.6293      38.0
# 181776  24337031  1970-01-02 00:28:01.789367   37.8797    12.9638      10.0
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
b=DATA.sort_values(by='Time')
counter=pd.Series([1 for i in range(len(DATA['Time']))])
counter.name='Count'
b=pd.concat([b,pd.Series(counter)],axis=1)
b=b['Count'].groupby(b['Time'])
b_sum=pd.Series(b.sum())
#sns.distplot(b_sum,kde=False) # frequency of earthquakes per count
#b_sum.index().tolist(b_sum)
b_sum_index=b_sum.index.values
plt.bar(b_sum_index,b_sum,edgecolor='navy') #edgecolor: bar color
plt.xlabel('Time')
plt.ylabel('N. of earthquakes')
# Out:
# Text(0, 0.5, 'N. of earthquakes')
