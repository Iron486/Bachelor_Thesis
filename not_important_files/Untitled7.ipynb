# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sns.set(style="darkgrid")
a=pd.read_csv("C:\\Users\Ogeid99\Desktop\DS\excel\catalogo_l'aquila.txt",sep='|')
time=a['Time'].iloc[:1000]
magnitude=a['Magnitude'].iloc[:1000]
#bin_magnitude=pd.Series(np.array(np.arange(np.min(magnitude),np.max(magnitude)+0.2,0.2)))
#number_of_earthquakes= pd.Series(np.array([np.count_nonzero((magnitude >= i ) & (magnitude <= i+0.2))
                                          # for i in bin_magnitude]))
#bin_magnitude=np.add(bin_magnitude,0.1)
plot=plt.scatter(time, magnitude, color='black',s=1)# palette= sets the colour of hue
#plt.xlim(datetime.date(2008, 10, 10), datetime.date(2009, 11, 30))   #plot.set(yscale="log")
plt.xticks(np.arange(1,101, 50)) #authomatically it considers dates
# Out:
# ([<matplotlib.axis.XTick at 0x28fe747cc48>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
longitude=a['Longitude'].iloc[:300]
latitude=a['Latitude'].iloc[:300]
sns.scatterplot(x='longitude',y='latitude',hue='bin_magnitude')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0d8186231de2> in <module>
#       1 longitude=a['Longitude'].iloc[:300]
#       2 latitude=a['Latitude'].iloc[:300]
# ----> 3 sns.scatterplot(x='longitude',y='latitude',hue='bin_magnitude')
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...
