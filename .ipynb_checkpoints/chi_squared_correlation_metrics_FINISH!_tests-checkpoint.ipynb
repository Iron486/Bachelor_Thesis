# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
df=pd.read_csv(r"C:\\Users\Ogeid99\Desktop\cataloguess\declustering_correlation_metrics.csv")
df
# Out:
#       Spacetime_distance  Mainshock  Aftershock  #EventID  \
# 0           2.885439e+07     1907.0         0.0  24328471
# 1           3.537832e+06        2.0         1.0  24326871
# 2           8.460595e+06        9.0         2.0  24326451
# 3           3.531638e+07     6208.0         3.0  24317311
# 4           2.325441e+06       36.0         4.0  24313381
# ...                  ...        ...         ...       ...
# 6491        1.261267e+08    11187.0     11181.0      1669
# 6492        8.658320e+07    11185.0     11183.0      1159
# 6493        9.783141e+05    11190.0     11184.0      1099
# 6494        1.676533e+05    11187.0     11185.0      1019
# 6495        1.353561e+07    11187.0     11186.0       809
#
#                             Time  Latitude  Longitude  Depth/Km  \
# 0     2020-04-28 13:00:30.050000   38.4607   13.64330      17.7
# 1     2020-04-28 07:14:45.750000   38.5943   14.17220      27.5
# 2     2020-04-28 05:57:28.820000   38.4052   13.60600      25.4
# 3     2020-04-26 02:59:02.450000   40.8285   14.15167       2.5
# 4     2020-04-25 07:21:54.480000   37.7523   14.61750      23.5
# ...                          ...       ...        ...       ...
# 6491     1985-01-19 15:34:58.090   40.4540   16.12700       8.3
# 6492     1985-01-12 17:41:12.700   39.4500   16.39100      13.3
# 6493     1985-01-11 20:30:36.530   37.4040   14.44300       5.0
# 6494     1985-01-10 19:29:44.730   39.6090   16.37100      10.0
# 6495     1985-01-09 03:13:01.090   43.3020   12.63800       4.0
#
#               Author  Catalog  Contributor  ContributorID MagType  Magnitude  \
# 0        SURVEY-INGV      NaN          NaN            NaN      ML        3.5
# 1        SURVEY-INGV      NaN          NaN            NaN      ML        3.0
# 2        SURVEY-INGV      NaN          NaN            NaN      ML        3.1
# 3     SURVEY-INGV-OV      NaN          NaN            NaN      Md        3.1
# 4      BULLETIN-INGV      NaN          NaN            NaN      ML        3.4
# ...              ...      ...          ...            ...     ...        ...
# 6491    BULLETIN-VAX      NaN          NaN            NaN      Md        3.0
# 6492    BULLETIN-VAX      NaN          NaN            NaN      Md        3.0
# 6493    BULLETIN-VAX      NaN          NaN            NaN      Md        3.3
# 6494    BULLETIN-VAX      NaN          NaN            NaN      Md        3.5
# 6495    BULLETIN-VAX      NaN          NaN            NaN      Md        3.3
#
#      MagAuthor                                EventLocationName  index
# 0           --                       Tirreno Meridionale (MARE)      0
# 1           --                       Tirreno Meridionale (MARE)      1
# 2           --  Costa Siciliana centro-settentrionale (Palermo)      2
# 3           --                             5 km E Pozzuoli (NA)      3
# 4           --                              4 km SE Troina (EN)      4
# ...        ...                                              ...    ...
# 6491        --                           5 km SW Accettura (MT)  11181
# 6492        --                                 4 km S Acri (CS)  11183
# 6493        --                              2 km SW Aidone (EN)  11184
# 6494        --                  5 km N San Demetrio Corone (CS)  11185
# 6495        --                              8 km SE Gubbio (PG)  11186
#
# [6496 rows x 17 columns]

# %%
import matplotlib.dates as mdates
df["Time"] = df["Time"].astype("datetime64")
fig, ax = plt.subplots(1,1)
ax.hist(df['Time'], bins=100, color='lightblue')
#ax.xaxis.set_major_locator(mdates.YearLocator())
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.show()

# %%
df.sort_values(by='Time',ascending=True,inplace=True)
num=pd.Series([i for i in reversed(range(0,int(df.size/len(df.columns))))])  #range(0,2,-1) gives [2,1], riversed gives [1,0]
df=pd.concat([df,num],axis=1)
df.set_index(0,inplace=True) #remember inplace

# %%
df=df.iloc[::-1]
starting_time=df['Time'].iloc[0]
end_time=df['Time'].iloc[6495]
diff_value=[]
for i in df.index:
    diff=(df['Time'].iloc[i]-starting_time).total_seconds()
    diff_value.append(diff)
diff_value=pd.Series(diff_value)
df=pd.concat([diff_value,df],axis=1)   
df.rename({0:'Diff_time'},axis=1,inplace=True)
df
# Out:
#          Diff_time  Spacetime_distance  Mainshock  Aftershock  #EventID  \
# 0     0.000000e+00        1.353561e+07    11187.0     11186.0       809
# 1     1.450036e+05        1.676533e+05    11187.0     11185.0      1019
# 2     2.350554e+05        9.783141e+05    11190.0     11184.0      1099
# 3     3.112916e+05        8.658320e+07    11185.0     11183.0      1159
# 4     9.085170e+05        1.261267e+08    11187.0     11181.0      1669
# ...            ...                 ...        ...         ...       ...
# 6491  1.113711e+09        2.325441e+06       36.0         4.0  24313381
# 6492  1.113782e+09        3.531638e+07     6208.0         3.0  24317311
# 6493  1.113965e+09        8.460595e+06        9.0         2.0  24326451
# 6494  1.113970e+09        3.537832e+06        2.0         1.0  24326871
# 6495  1.113990e+09        2.885439e+07     1907.0         0.0  24328471
#
#                         Time  Latitude  Longitude  Depth/Km          Author  \
# 0    1985-01-09 03:13:01.090   43.3020   12.63800       4.0    BULLETIN-VAX
# 1    1985-01-10 19:29:44.730   39.6090   16.37100      10.0    BULLETIN-VAX
# 2    1985-01-11 20:30:36.530   37.4040   14.44300       5.0    BULLETIN-VAX
# 3    1985-01-12 17:41:12.700   39.4500   16.39100      13.3    BULLETIN-VAX
# 4    1985-01-19 15:34:58.090   40.4540   16.12700       8.3    BULLETIN-VAX
# ...                      ...       ...        ...       ...             ...
# 6491 2020-04-25 07:21:54.480   37.7523   14.61750      23.5   BULLETIN-INGV
# 6492 2020-04-26 02:59:02.450   40.8285   14.15167       2.5  SURVEY-INGV-OV
# 6493 2020-04-28 05:57:28.820   38.4052   13.60600      25.4     SURVEY-INGV
# 6494 2020-04-28 07:14:45.750   38.5943   14.17220      27.5     SURVEY-INGV
# 6495 2020-04-28 13:00:30.050   38.4607   13.64330      17.7     SURVEY-INGV
#
#       Catalog  Contributor  ContributorID MagType  Magnitude MagAuthor  \
# 0         NaN          NaN            NaN      Md        3.3        --
# 1         NaN          NaN            NaN      Md        3.5        --
# 2         NaN          NaN            NaN      Md        3.3        --
# 3         NaN          NaN            NaN      Md        3.0        --
# 4         NaN          NaN            NaN      Md        3.0        --
# ...       ...          ...            ...     ...        ...       ...
# 6491      NaN          NaN            NaN      ML        3.4        --
# 6492      NaN          NaN            NaN      Md        3.1        --
# 6493      NaN          NaN            NaN      ML        3.1        --
# 6494      NaN          NaN            NaN      ML        3.0        --
# 6495      NaN          NaN            NaN      ML        3.5        --
#
#                                     EventLocationName  index
# 0                                 8 km SE Gubbio (PG)  11186
# 1                     5 km N San Demetrio Corone (CS)  11185
# 2                                 2 km SW Aidone (EN)  11184
# 3                                    4 km S Acri (CS)  11183
# 4                              5 km SW Accettura (MT)  11181
# ...                                               ...    ...
# 6491                              4 km SE Troina (EN)      4
# 6492                             5 km E Pozzuoli (NA)      3
# 6493  Costa Siciliana centro-settentrionale (Palermo)      2
# 6494                       Tirreno Meridionale (MARE)      1
# 6495                       Tirreno Meridionale (MARE)      0
#
# [6496 rows x 18 columns]

# %%
a=df[(df['Magnitude']>2.9 )& (df['Time']>datetime.datetime(1985,1,1,1,1,1))& (df['Time']<datetime.datetime(2020,1,1,1,1,1))]

a#.first_valid_index()
# Out:
#          Diff_time  Spacetime_distance  Mainshock  Aftershock  #EventID  \
# 0     0.000000e+00        1.353561e+07    11187.0     11186.0       809
# 1     1.450036e+05        1.676533e+05    11187.0     11185.0      1019
# 2     2.350554e+05        9.783141e+05    11190.0     11184.0      1099
# 3     3.112916e+05        8.658320e+07    11185.0     11183.0      1159
# 4     9.085170e+05        1.261267e+08    11187.0     11181.0      1669
# ...            ...                 ...        ...         ...       ...
# 6418  1.102395e+09        3.062123e+05      104.0        85.0  23605481
# 6419  1.102538e+09        6.061132e+07      119.0        80.0  23614031
# 6420  1.102771e+09        5.516232e+06      288.0        79.0  23625961
# 6421  1.103242e+09        9.306001e+07     2046.0        78.0  23665851
# 6422  1.103480e+09        2.212217e+06      115.0        77.0  23683571
#
#                         Time  Latitude  Longitude  Depth/Km         Author  \
# 0    1985-01-09 03:13:01.090   43.3020    12.6380       4.0   BULLETIN-VAX
# 1    1985-01-10 19:29:44.730   39.6090    16.3710      10.0   BULLETIN-VAX
# 2    1985-01-11 20:30:36.530   37.4040    14.4430       5.0   BULLETIN-VAX
# 3    1985-01-12 17:41:12.700   39.4500    16.3910      13.3   BULLETIN-VAX
# 4    1985-01-19 15:34:58.090   40.4540    16.1270       8.3   BULLETIN-VAX
# ...                      ...       ...        ...       ...            ...
# 6418 2019-12-16 08:06:33.940   41.0692    14.7390      10.9  BULLETIN-INGV
# 6419 2019-12-17 23:48:44.370   37.8385    14.9353      28.3  BULLETIN-INGV
# 6420 2019-12-20 16:31:54.020   37.2837    16.4213      38.1  BULLETIN-INGV
# 6421 2019-12-26 03:17:45.240   43.1902    12.9332      62.0  BULLETIN-INGV
# 6422 2019-12-28 21:32:55.290   40.5857    15.7903      16.0  BULLETIN-INGV
#
#       Catalog  Contributor  ContributorID MagType  Magnitude MagAuthor  \
# 0         NaN          NaN            NaN      Md        3.3        --
# 1         NaN          NaN            NaN      Md        3.5        --
# 2         NaN          NaN            NaN      Md        3.3        --
# 3         NaN          NaN            NaN      Md        3.0        --
# 4         NaN          NaN            NaN      Md        3.0        --
# ...       ...          ...            ...     ...        ...       ...
# 6418      NaN          NaN            NaN      Mw        3.6        --
# 6419      NaN          NaN            NaN      ML        3.5        --
# 6420      NaN          NaN            NaN      ML        3.0        --
# 6421      NaN          NaN            NaN      ML        3.3        --
# 6422      NaN          NaN            NaN      ML        3.0        --
#
#                       EventLocationName  index
# 0                   8 km SE Gubbio (PG)  11186
# 1       5 km N San Demetrio Corone (CS)  11185
# 2                   2 km SW Aidone (EN)  11184
# 3                      4 km S Acri (CS)  11183
# 4                5 km SW Accettura (MT)  11181
# ...                                 ...    ...
# 6418  2 km W San Leucio del Sannio (BN)     85
# 6419               5 km S Randazzo (CT)     80
# 6420       Mar Ionio Meridionale (MARE)     79
# 6421                     Fiuminata (MC)     78
# 6422               1 km NE Pignola (PZ)     77
#
# [6423 rows x 18 columns]

# %%
starting_time1=a['Time'].iloc[0]
end_time1=a['Time'].iloc[len(a.index)-1]
diff_time=int((((((end_time1-starting_time1).total_seconds())))-3600*24*365*10)/(3600*24*10))
events_interval=[]
diff_value=[]
for i in range(len(a.index)):
    diff=(a['Time'].iloc[i]-starting_time1).total_seconds()
    diff_value.append(diff)
a['Diff_time']=diff_value
#a=pd.concat([diff_value,a],axis=1) 
cnt=0
while cnt <diff_time:  #890
    condition=a[(a['Diff_time']>=(864000*cnt))&(a['Diff_time']<(315360000+(864000*cnt)))].loc[:,'Diff_time']
    condition1=condition.to_list()
    events_interval.append(condition1)
    cnt+=1
#events_interval 
#diff_time
# Out:
# C:\Users\Ogeid99\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
number_time=pd.DataFrame(events_interval)
number_time
# Out:
#              0             1             2             3             4     \
# 0    0.000000e+00  1.450036e+05  2.350554e+05  3.112916e+05  9.085170e+05
# 1    9.085170e+05  9.455241e+05  1.047715e+06  1.068151e+06  1.191038e+06
# 2    2.236896e+06  2.483416e+06  2.537637e+06  2.556360e+06  2.586771e+06
# 3    2.724564e+06  3.021573e+06  3.171643e+06  3.306076e+06  3.366576e+06
# 4    3.576475e+06  3.589606e+06  3.604323e+06  3.726685e+06  3.768453e+06
# ..            ...           ...           ...           ...           ...
# 907  7.836512e+08  7.836640e+08  7.836746e+08  7.837928e+08  7.843217e+08
# 908  7.848548e+08  7.850416e+08  7.852712e+08  7.854371e+08  7.855912e+08
# 909  7.854371e+08  7.855912e+08  7.856326e+08  7.857969e+08  7.860184e+08
# 910  7.864594e+08  7.865555e+08  7.867894e+08  7.867943e+08  7.869330e+08
# 911  7.871121e+08  7.871126e+08  7.871132e+08  7.871211e+08  7.871213e+08
#
#              5             6             7             8             9     \
# 0    9.455241e+05  1.047715e+06  1.068151e+06  1.191038e+06  1.203080e+06
# 1    1.203080e+06  1.234637e+06  1.455611e+06  2.236896e+06  2.483416e+06
# 2    2.724564e+06  3.021573e+06  3.171643e+06  3.306076e+06  3.366576e+06
# 3    3.576475e+06  3.589606e+06  3.604323e+06  3.726685e+06  3.768453e+06
# 4    3.840152e+06  3.913216e+06  4.051295e+06  4.203557e+06  4.269198e+06
# ..            ...           ...           ...           ...           ...
# 907  7.848548e+08  7.850416e+08  7.852712e+08  7.854371e+08  7.855912e+08
# 908  7.856326e+08  7.857969e+08  7.860184e+08  7.861987e+08  7.864594e+08
# 909  7.861987e+08  7.864594e+08  7.865555e+08  7.867894e+08  7.867943e+08
# 910  7.870035e+08  7.871121e+08  7.871126e+08  7.871132e+08  7.871211e+08
# 911  7.871214e+08  7.871227e+08  7.871249e+08  7.871382e+08  7.871430e+08
#
#      ...  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010
# 0    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 907  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 908  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 909  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 910  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 911  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [912 rows x 2011 columns]

# %%
number_time_count=number_time.count(axis=1)
#lista=[i for i in range(130)]
#lista_fin=[i for i in range (880,890)]
#number_time_count.drop(lista,inplace=True)
#number_time_count.drop(lista_fin,inplace=True)
number_time_count
# Out:
# 0      1853
# 1      1851
# 2      1844
# 3      1841
# 4      1839
#        ...
# 907    1867
# 908    1869
# 909    1871
# 910    1868
# 911    1874
# Length: 912, dtype: int64

# %%
plt.hist(number_time_count,bins=12)
# Out:
# (array([ 55.,  70.,  65.,  26.,  89.,  66.,  69., 102.,  82., 123., 122.,
#          43.]),
#  array([1589.        , 1624.16666667, 1659.33333333, 1694.5       ,
#         1729.66666667, 1764.83333333, 1800.        , 1835.16666667,
#         1870.33333333, 1905.5       , 1940.66666667, 1975.83333333,
#         2011.        ]),
#  <a list of 12 Patch objects>)

# %%
import random
nt=number_time_count.to_numpy()
chi=[]
p_val=[]
for i in range(3000):
    random.shuffle(nt)
    #nt_reshape=np.reshape(nt,(len(nt),1))
    nt_choice=[np.random.choice(nt) for i in range(31)]
    from statistics import mean 
    from scipy.stats import chisquare, chi2_contingency
    s=np.random.poisson(np.mean(nt_choice),len(nt_choice))
    #chi2_contingency(number_time_count,s)
    test,d=chisquare(nt_choice,s)
    chi.append(test)
chi
mean(chi)
# Out:
# 253.0063754926072

# %%
plt.hist(s,bins=6)
# Out:
# (array([ 22., 177., 402., 319.,  66.,  14.]),
#  array([13.        , 19.16666667, 25.33333333, 31.5       , 37.66666667,
#         43.83333333, 50.        ]),
#  <a list of 6 Patch objects>)

# %%
list(number_time_count)
# Out:
# [145,
#  133,
#  139,
#  138,
#  108,
#  121,
#  158,
#  132,
#  115,
#  109,
#  109,
#  131,
#  113,
#  139,
#  116,
#  153,
#  138,
#  112,
#  146,
#  148,
#  106,
#  112,
#  147,
#  113,
#  121,
#  122,
#  120,
#  147,
#  122,
#  129,
#  140,
#  115,
#  114,
#  105,
#  156,
#  116,
#  121,
#  108,
#  127,
#  108,
#  152,
#  122,
#  121,
#  121,
#  134,
#  108,
#  127,
#  135,
#  112,
#  147,
#  121,
#  115,
#  110,
#  131,
#  121,
#  115,
#  131,
#  121,
#  105,
#  136,
#  129,
#  135,
#  113,
#  117,
#  121,
#  122,
#  119,
#  151,
#  111,
#  120,
#  128,
#  120,
#  153,
#  116,
#  131,
#  131,
#  122,
#  134,
#  139,
#  122,
#  111,
#  130,
#  123,
#  162,
#  121,
#  125,
#  122,
#  120,
#  119,
#  160,
#  122,
#  123,
#  104,
#  122,
#  135,
#  119,
#  127,
#  161,
#  110,
#  103,
#  121,
#  112,
#  115,
#  114,
#  121,
#  121,
#  151,
#  111,
#  140,
#  170,
#  122,
#  156,
#  120,
#  135,
#  120,
#  145,
#  120,
#  134,
#  109,
#  122,
#  115,
#  153,
#  121,
#  113,
#  143,
#  106,
#  134,
#  131,
#  153,
#  120,
#  120,
#  120,
#  121,
#  109,
#  113,
#  132,
#  119,
#  115,
#  115,
#  108,
#  140,
#  131,
#  145,
#  114,
#  132,
#  111,
#  157,
#  126,
#  155,
#  146,
#  108,
#  132,
#  103,
#  121,
#  121,
#  145,
#  115,
#  112,
#  113,
#  112,
#  120,
#  110,
#  150,
#  126,
#  157,
#  144,
#  131,
#  112,
#  127,
#  121,
#  152,
#  130,
#  107,
#  150,
#  122,
#  134,
#  109,
#  127,
#  123,
#  132,
#  112,
#  120,
#  147,
#  114,
#  111,
#  150,
#  169,
#  152,
#  146,
#  99,
#  120,
#  112,
#  139,
#  127,
#  140,
#  107,
#  114,
#  132,
#  132,
#  132,
#  112,
#  115,
#  122,
#  156,
#  122,
#  113,
#  106,
#  127,
#  157,
#  113,
#  119,
#  130,
#  123,
#  162,
#  111,
#  121,
#  114,
#  130,
#  112,
#  133,
#  111,
#  131,
#  121,
#  119,
#  147,
#  142,
#  127,
#  122,
#  161,
#  128,
#  116,
#  155,
#  132,
#  121,
#  148,
#  147,
#  129,
#  139,
#  108,
#  131,
#  123,
#  144,
#  123,
#  116,
#  130,
#  121,
#  113,
#  130,
#  115,
#  156,
#  129,
#  155,
#  130,
#  116,
#  114,
#  103,
#  132,
#  130,
#  124,
#  127,
#  122,
#  120,
#  151,
#  113,
#  112,
#  112,
#  120,
#  116,
#  123,
#  127,
#  134,
#  156,
#  148,
#  146,
#  114,
#  132,
#  132,
#  112,
#  147,
#  113,
#  121,
#  119,
#  154,
#  115,
#  104,
#  131,
#  123,
#  121,
#  123,
#  112,
#  139,
#  104,
#  115,
#  110,
#  130,
#  122,
#  123,
#  112,
#  131,
#  111,
#  144,
#  111,
#  148,
#  125,
#  158,
#  121,
#  154,
#  113,
#  121,
#  127,
#  121,
#  116,
#  108,
#  111,
#  113,
#  113,
#  106,
#  144,
#  111,
#  145,
#  144,
#  131,
#  112,
#  162,
#  121,
#  123,
#  111,
#  120,
#  107,
#  146,
#  153,
#  134,
#  134,
#  126,
#  167,
#  120,
#  130,
#  120,
#  130,
#  121,
#  114,
#  116,
#  113,
#  120,
#  122,
#  113,
#  104,
#  116,
#  116,
#  121,
#  113,
#  115,
#  113,
#  131,
#  112,
#  147,
#  122,
#  112,
#  147,
#  133,
#  122,
#  103,
#  111,
#  115,
#  146,
#  121,
#  128,
#  129,
#  120,
#  139,
#  112,
#  123,
#  99,
#  127,
#  134,
#  127,
#  114,
#  113,
#  113,
#  105,
#  122,
#  124,
#  148,
#  120,
#  109,
#  112,
#  121,
#  147,
#  122,
#  139,
#  120,
#  106,
#  109,
#  119,
#  116,
#  109,
#  150,
#  136,
#  111,
#  155,
#  133,
#  123,
#  124,
#  112,
#  120,
#  120,
#  151,
#  112,
#  121,
#  155,
#  171,
#  120,
#  131,
#  140,
#  107,
#  116,
#  113,
#  121,
#  154,
#  112,
#  112,
#  154,
#  156,
#  140,
#  150,
#  126,
#  126,
#  156,
#  121,
#  150,
#  138,
#  139,
#  132,
#  147,
#  132,
#  155,
#  113,
#  122,
#  127,
#  122,
#  123,
#  162,
#  148,
#  121,
#  147,
#  116,
#  131,
#  99,
#  107,
#  134,
#  119,
#  145,
#  122,
#  111,
#  108,
#  113,
#  127,
#  122,
#  122,
#  121,
#  147,
#  121,
#  159,
#  135,
#  112,
#  121,
#  104,
#  122,
#  120,
#  155,
#  121,
#  120,
#  155,
#  146,
#  127,
#  115,
#  121,
#  131,
#  140,
#  112,
#  111,
#  116,
#  113,
#  133,
#  113,
#  135,
#  146,
#  156,
#  111,
#  120,
#  128,
#  111,
#  112,
#  113,
#  119,
#  121,
#  154,
#  119,
#  115,
#  138,
#  145,
#  125,
#  132,
#  137,
#  150,
#  135,
#  161,
#  133,
#  148,
#  115,
#  122,
#  114,
#  146,
#  157,
#  169,
#  109,
#  111,
#  154,
#  140,
#  110]

# %%
a=df[(df['Magnitude']>4.8)& (df['Time']>datetime.datetime(1985,1,1,1,1))& (df['Time']<datetime.datetime(2020,1,1,1,1,1))]

starting_time1=a['Time'].iloc[0]
end_time1=a['Time'].iloc[len(a.index)-1]
diff_time=int((((((end_time1-starting_time1).total_seconds())))-3600*24*365*10)/(3600*24*10))
events_interval=[]
diff_value=[]
for i in range(len(a.index)):
    diff=(a['Time'].iloc[i]-starting_time1).total_seconds()
    diff_value.append(diff)
a['Diff_time']=diff_value
cnt=0
while cnt <diff_time:  #890
    condition=a[(a['Diff_time']>=(864000*cnt))&(a['Diff_time']<(315360000+(864000*cnt)))].loc[:,'Diff_time']
    condition1=condition.to_list()
    events_interval.append(condition1)
    cnt+=1
number_time=pd.DataFrame(events_interval)
number_time_count=number_time.count(axis=1)
import random
nt=number_time_count.to_numpy()
chi=[]
p_val=[]
for i in range(1000):
    random.shuffle(nt)
    #nt_reshape=np.reshape(nt,(len(nt),1))
    nt_choice=[np.random.choice(nt) for u in range(31)]
    from statistics import mean 
    from scipy.stats import chisquare, chi2_contingency
    s=np.random.poisson(np.mean(nt),len(nt_choice))
    #chi2_contingency(number_time_count,s)
    test,d=chisquare(nt_choice,s)
    chi.append(test)
mean(chi)
# Out:
# C:\Users\Ogeid99\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Ogeid99\anaconda3\lib\site-packages\scipy\stats\stats.py:5745: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs - f_exp)**2 / f_exp
# inf

# %%
plt.hist(nt,bins=5)
# Out:
# (array([171., 222., 191.,  54., 251.]),
#  array([ 4. ,  6.4,  8.8, 11.2, 13.6, 16. ]),
#  <a list of 5 Patch objects>)

# %%
df.drop_duplicates(subset='Mainshock',inplace=True)
df
# Out:
#          Diff_time  Spacetime_distance  Mainshock  Aftershock  #EventID  \
# 0     0.000000e+00        1.353561e+07    11187.0     11186.0       809
# 2     2.350554e+05        9.783141e+05    11190.0     11184.0      1099
# 3     3.112916e+05        8.658320e+07    11185.0     11183.0      1159
# 5     9.455241e+05        3.448084e+07    11181.0     11180.0      1729
# 7     1.068151e+06        1.804994e+10    11179.0     11178.0      1879
# ...            ...                 ...        ...         ...       ...
# 6491  1.113711e+09        2.325441e+06       36.0         4.0  24313381
# 6492  1.113782e+09        3.531638e+07     6208.0         3.0  24317311
# 6493  1.113965e+09        8.460595e+06        9.0         2.0  24326451
# 6494  1.113970e+09        3.537832e+06        2.0         1.0  24326871
# 6495  1.113990e+09        2.885439e+07     1907.0         0.0  24328471
#
#                         Time  Latitude  Longitude  Depth/Km          Author  \
# 0    1985-01-09 03:13:01.090   43.3020   12.63800       4.0    BULLETIN-VAX
# 2    1985-01-11 20:30:36.530   37.4040   14.44300       5.0    BULLETIN-VAX
# 3    1985-01-12 17:41:12.700   39.4500   16.39100      13.3    BULLETIN-VAX
# 5    1985-01-20 01:51:45.190   45.5230   15.08600       6.3    BULLETIN-VAX
# 7    1985-01-21 11:55:31.710   38.5610   15.47000     215.1    BULLETIN-VAX
# ...                      ...       ...        ...       ...             ...
# 6491 2020-04-25 07:21:54.480   37.7523   14.61750      23.5   BULLETIN-INGV
# 6492 2020-04-26 02:59:02.450   40.8285   14.15167       2.5  SURVEY-INGV-OV
# 6493 2020-04-28 05:57:28.820   38.4052   13.60600      25.4     SURVEY-INGV
# 6494 2020-04-28 07:14:45.750   38.5943   14.17220      27.5     SURVEY-INGV
# 6495 2020-04-28 13:00:30.050   38.4607   13.64330      17.7     SURVEY-INGV
#
#       Catalog  Contributor  ContributorID MagType  Magnitude MagAuthor  \
# 0         NaN          NaN            NaN      Md        3.3        --
# 2         NaN          NaN            NaN      Md        3.3        --
# 3         NaN          NaN            NaN      Md        3.0        --
# 5         NaN          NaN            NaN      Md        3.6        --
# 7         NaN          NaN            NaN      Md        3.4        --
# ...       ...          ...            ...     ...        ...       ...
# 6491      NaN          NaN            NaN      ML        3.4        --
# 6492      NaN          NaN            NaN      Md        3.1        --
# 6493      NaN          NaN            NaN      ML        3.1        --
# 6494      NaN          NaN            NaN      ML        3.0        --
# 6495      NaN          NaN            NaN      ML        3.5        --
#
#                                     EventLocationName  index
# 0                                 8 km SE Gubbio (PG)  11186
# 2                                 2 km SW Aidone (EN)  11184
# 3                                    4 km S Acri (CS)  11183
# 5        Confine Slovenia-Croazia (SLOVENIA, CROAZIA)  11180
# 7                          Tirreno Meridionale (MARE)  11178
# ...                                               ...    ...
# 6491                              4 km SE Troina (EN)      4
# 6492                             5 km E Pozzuoli (NA)      3
# 6493  Costa Siciliana centro-settentrionale (Palermo)      2
# 6494                       Tirreno Meridionale (MARE)      1
# 6495                       Tirreno Meridionale (MARE)      0
#
# [2980 rows x 18 columns]

# %%
DATA=pd.read_csv(r"C:\\Users\Ogeid99\Desktop\cataloguess\DATA3_magn.csv")
DATA
# Out:
#        #EventID                        Time  Latitude  Longitude  Depth/Km  \
# 0           199  1985-01-04T16:57:40.240000   46.1580    7.17400      10.0
# 1           229  1985-01-04T23:59:54.820000   45.3380    6.64100       5.0
# 2           239  1985-01-05T03:47:03.640000   45.4090    6.62700      10.0
# 3           489  1985-01-06T17:22:58.540000   39.2910   16.76500       5.0
# 4           529  1985-01-07T00:34:49.290000   43.2250   12.73000      10.0
# ...         ...                         ...       ...        ...       ...
# 11189  24313381  2020-04-25T07:21:54.480000   37.7523   14.61750      23.5
# 11190  24317311  2020-04-26T02:59:02.450000   40.8285   14.15167       2.5
# 11191  24326451  2020-04-28T05:57:28.820000   38.4052   13.60600      25.4
# 11192  24326871  2020-04-28T07:14:45.750000   38.5943   14.17220      27.5
# 11193  24328471  2020-04-28T13:00:30.050000   38.4607   13.64330      17.7
#
#                Author  Catalog  Contributor  ContributorID MagType  Magnitude  \
# 0        BULLETIN-VAX      NaN          NaN            NaN       M        3.8
# 1        BULLETIN-VAX      NaN          NaN            NaN       M        3.7
# 2        BULLETIN-VAX      NaN          NaN            NaN       M        3.2
# 3        BULLETIN-VAX      NaN          NaN            NaN      Md        3.0
# 4        BULLETIN-VAX      NaN          NaN            NaN      Md        3.0
# ...               ...      ...          ...            ...     ...        ...
# 11189   BULLETIN-INGV      NaN          NaN            NaN      ML        3.4
# 11190  SURVEY-INGV-OV      NaN          NaN            NaN      Md        3.1
# 11191     SURVEY-INGV      NaN          NaN            NaN      ML        3.1
# 11192     SURVEY-INGV      NaN          NaN            NaN      ML        3.0
# 11193     SURVEY-INGV      NaN          NaN            NaN      ML        3.5
#
#       MagAuthor                                EventLocationName
# 0            --               Confine Italia-Svizzera (SVIZZERA)
# 1            --                 Confine Italia-Francia (FRANCIA)
# 2            --                 Confine Italia-Francia (FRANCIA)
# 3            --                         2 km N Castelsilano (KR)
# 4            --                        5 km W Gualdo Tadino (PG)
# ...         ...                                              ...
# 11189        --                              4 km SE Troina (EN)
# 11190        --                             5 km E Pozzuoli (NA)
# 11191        --  Costa Siciliana centro-settentrionale (Palermo)
# 11192        --                       Tirreno Meridionale (MARE)
# 11193        --                       Tirreno Meridionale (MARE)
#
# [11194 rows x 13 columns]

# %%
df.set_index('Mainshock',inplace=True)

# %%
indicisss=pd.Series((df.index.values).astype(np.int64))
indicisss.rename('indici',inplace=True)  #,inplace=True)
indicisss.to_frame()
# Out:
#       indici
# 0      11187
# 1      11190
# 2      11185
# 3      11181
# 4      11179
# ...      ...
# 2975      36
# 2976    6208
# 2977       9
# 2978       2
# 2979    1907
#
# [2980 rows x 1 columns]

# %%
df=pd.merge(indicisss,DATA,how='left',left_on='indici',right_index=True)
df
# Out:
#       indici  #EventID                        Time  Latitude  Longitude  \
# 0      11187  24310151  2020-04-24T14:28:15.390000   37.7685   14.08580
# 1      11190  24317311  2020-04-26T02:59:02.450000   40.8285   14.15167
# 2      11185  24295961  2020-04-21T21:48:49.170000   39.7113   15.42400
# 3      11181  24273191  2020-04-16T11:16:45.130000   44.6502    9.39720
# 4      11179  24269831  2020-04-15T20:02:54.740000   44.6525    9.39230
# ...      ...       ...                         ...       ...        ...
# 2975      36      5029  1985-02-22T13:55:33.450000   42.4330   13.31100
# 2976    6208   1438949  2003-05-18T23:43:37.660000   43.1570   12.80100
# 2977       9      1099  1985-01-11T20:30:36.530000   37.4040   14.44300
# 2978       2       239  1985-01-05T03:47:03.640000   45.4090    6.62700
# 2979    1907    398669  1991-06-22T21:10:18.220000   42.9840   13.00400
#
#       Depth/Km          Author  Catalog  Contributor  ContributorID MagType  \
# 0         36.1   BULLETIN-INGV      NaN          NaN            NaN      ML
# 1          2.5  SURVEY-INGV-OV      NaN          NaN            NaN      Md
# 2          5.7     SURVEY-INGV      NaN          NaN            NaN      ML
# 3          7.2   BULLETIN-INGV      NaN          NaN            NaN      ML
# 4          7.1   BULLETIN-INGV      NaN          NaN            NaN      ML
# ...        ...             ...      ...          ...            ...     ...
# 2975       7.0    BULLETIN-VAX      NaN          NaN            NaN      Md
# 2976       8.9    BULLETIN-VAX      NaN          NaN            NaN      Md
# 2977       5.0    BULLETIN-VAX      NaN          NaN            NaN      Md
# 2978      10.0    BULLETIN-VAX      NaN          NaN            NaN       M
# 2979       5.0    BULLETIN-VAX      NaN          NaN            NaN      Md
#
#       Magnitude MagAuthor                 EventLocationName
# 0           3.5        --                2 km NE Blufi (PA)
# 1           3.1        --              5 km E Pozzuoli (NA)
# 2           3.0        --        Tirreno Meridionale (MARE)
# 3           3.5        --            5 km SE Cerignale (PC)
# 4           3.5        --            4 km SE Cerignale (PC)
# ...         ...       ...                               ...
# 2975        3.3        --               1 km E Pizzoli (AQ)
# 2976        3.0        --          5 km N Nocera Umbra (PG)
# 2977        3.3        --               2 km SW Aidone (EN)
# 2978        3.2        --  Confine Italia-Francia (FRANCIA)
# 2979        3.1        --         1 km S Monte Cavallo (MC)
#
# [2980 rows x 14 columns]

# %%
df.sort_values(by='indici',ascending=True,inplace=True)
#num=pd.Series([i for i in reversed(range(0,int(df.size/len(df.columns))))])  #range(0,2,-1) gives [2,1], riversed gives [1,0]
#df=pd.concat([df,num],axis=1)
df.set_index('indici',inplace=True) #remember inplace
#df=df.iloc[::-1]
df
# Out:
#         #EventID                        Time  Latitude  Longitude  Depth/Km  \
# indici
# 2            239  1985-01-05T03:47:03.640000   45.4090    6.62700      10.0
# 9           1099  1985-01-11T20:30:36.530000   37.4040   14.44300       5.0
# 13          1729  1985-01-20T01:51:45.190000   45.5230   15.08600       6.3
# 14          1859  1985-01-21T06:14:56.440000   41.2960   14.52800      10.0
# 21          3239  1985-02-06T21:03:17.090000   39.6470   16.81900       7.2
# ...          ...                         ...       ...        ...       ...
# 11184   24286931  2020-04-19T09:53:40.820000   45.0328    9.21080      25.0
# 11185   24295961  2020-04-21T21:48:49.170000   39.7113   15.42400       5.7
# 11186   24303781  2020-04-23T11:46:48.660000   37.7565   14.56220      36.0
# 11187   24310151  2020-04-24T14:28:15.390000   37.7685   14.08580      36.1
# 11190   24317311  2020-04-26T02:59:02.450000   40.8285   14.15167       2.5
#
#                 Author  Catalog  Contributor  ContributorID MagType  \
# indici
# 2         BULLETIN-VAX      NaN          NaN            NaN       M
# 9         BULLETIN-VAX      NaN          NaN            NaN      Md
# 13        BULLETIN-VAX      NaN          NaN            NaN      Md
# 14        BULLETIN-VAX      NaN          NaN            NaN      Md
# 21        BULLETIN-VAX      NaN          NaN            NaN      Md
# ...                ...      ...          ...            ...     ...
# 11184    BULLETIN-INGV      NaN          NaN            NaN      ML
# 11185      SURVEY-INGV      NaN          NaN            NaN      ML
# 11186      SURVEY-INGV      NaN          NaN            NaN      ML
# 11187    BULLETIN-INGV      NaN          NaN            NaN      ML
# 11190   SURVEY-INGV-OV      NaN          NaN            NaN      Md
#
#         Magnitude MagAuthor                             EventLocationName
# indici
# 2             3.2        --              Confine Italia-Francia (FRANCIA)
# 9             3.3        --                           2 km SW Aidone (EN)
# 13            3.6        --  Confine Slovenia-Croazia (SLOVENIA, CROAZIA)
# 14            3.2        --                   2 km NW San Lorenzello (BN)
# 21            3.4        --              Costa Ionica Cosentina (Cosenza)
# ...           ...       ...                                           ...
# 11184         3.7        --                        1 km SE Redavalle (PV)
# 11185         3.0        --                    Tirreno Meridionale (MARE)
# 11186         3.0        --                           5 km SW Troina (EN)
# 11187         3.5        --                            2 km NE Blufi (PA)
# 11190         3.1        --                          5 km E Pozzuoli (NA)
#
# [2980 rows x 13 columns]

# %%
import datetime
datetime_object = lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f')
split_object=lambda i: i.replace("T"," ") #for i in time_plot
df['Time']=df['Time'].map(split_object)
df['Time']=df['Time'].map(datetime_object)

# %%
a=df[(df['Magnitude']>3.5)& (df['Time']>datetime.datetime(1985,1,1,1,1))& (df['Time']<datetime.datetime(2020,4,1,1,1,1))]

starting_time1=a['Time'].iloc[0]
end_time1=a['Time'].iloc[len(a.index)-1]
diff_time=int((((((end_time1-starting_time1).total_seconds())))-3600*24*365*10)/(3600*24*10))
events_interval=[]
diff_value=[]
for i in range(len(a.index)):
    diff=(a['Time'].iloc[i]-starting_time1).total_seconds()
    diff_value.append(diff)
a['Diff_time']=diff_value
cnt=0
while cnt <diff_time:  #890
    condition=a[(a['Diff_time']>=(864000*cnt))&(a['Diff_time']<(315360000+(864000*cnt)))].loc[:,'Diff_time']
    condition1=condition.to_list()
    events_interval.append(condition1)
    cnt+=1
number_time=pd.DataFrame(events_interval)
number_time_count=number_time.count(axis=1)
import random
nt=number_time_count.to_numpy()
chi=[]
p_val=[]
for i in range(1000):
    random.shuffle(nt)
    #nt_reshape=np.reshape(nt,(len(nt),1))
    nt_choice=[np.random.choice(nt) for u in range(31)]
    from statistics import mean 
    from scipy.stats import chisquare, chi2_contingency
    s=np.random.poisson(np.mean(nt),len(nt_choice))
    s.sort()
    nt_choice.sort()
    #chi2_contingency(number_time_count,s)
    test,d=chisquare(nt_choice,s)
    chi.append(test)
mean(chi)
# Out:
# C:\Users\Ogeid99\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 360.6946228248433

# %%
nt
# Out:
# array([183, 205, 214, 311, 178, 239, 287, 181, 267, 259, 286, 265, 302,
#        256, 303, 267, 458, 303, 304, 191, 208, 268, 266, 185, 428, 265,
#        185, 178, 377, 285, 310, 247, 266, 451, 167, 289, 300, 273, 311,
#        445, 302, 185, 406, 225, 171, 300, 448, 226, 184, 311, 306, 450,
#        214, 270, 288, 287, 267, 268, 299, 178, 269, 172, 272, 456, 450,
#        447, 455, 208, 244, 170, 395, 309, 301, 266, 287, 182, 173, 269,
#        181, 427, 181, 301, 244, 319, 447, 283, 181, 262, 266, 276, 287,
#        184, 263, 434, 255, 269, 310, 304, 260, 215, 422, 288, 303, 184,
#        192, 236, 428, 287, 293, 261, 453, 284, 232, 187, 430, 275, 410,
#        225, 303, 310, 306, 309, 182, 226, 221, 302, 452, 183, 306, 219,
#        265, 262, 266, 440, 264, 239, 450, 215, 260, 268, 405, 188, 249,
#        190, 245, 388, 304, 191, 168, 449, 311, 300, 279, 287, 267, 189,
#        171, 310, 425, 190, 176, 268, 209, 311, 269, 300, 185, 264, 187,
#        436, 169, 457, 302, 386, 246, 282, 451, 238, 247, 171, 303, 293,
#        307, 299, 245, 285, 259, 247, 452, 169, 431, 185, 305, 245, 288,
#        196, 293, 273, 452, 255, 180, 204, 300, 288, 288, 246, 377, 245,
#        266, 267, 268, 293, 263, 187, 306, 413, 452, 222, 255, 201, 431,
#        274, 214, 232, 311, 228, 217, 270, 444, 447, 449, 250, 457, 179,
#        300, 303, 304, 210, 295, 292, 267, 308, 193, 301, 224, 185, 285,
#        301, 190, 247, 457, 237, 451, 306, 177, 182, 182, 239, 267, 259,
#        421, 181, 169, 190, 407, 303, 312, 270, 421, 447, 457, 182, 188,
#        410, 452, 459, 225, 172, 216, 287, 262, 208, 432, 215, 263, 192,
#        456, 447, 181, 185, 168, 186, 303, 286, 187, 168, 245, 300, 247,
#        288, 238, 268, 441, 413, 268, 185, 196, 448, 300, 245, 208, 415,
#        457, 226, 303, 301, 272, 312, 304, 261, 177, 299, 177, 268, 301,
#        445, 452, 283, 448, 215, 265, 179, 258, 310, 456, 179, 181, 448,
#        454, 419, 210, 301, 436, 258, 303, 167, 265, 195, 254, 288, 285,
#        193, 212, 282, 428, 261, 312, 189, 209, 250, 454, 447, 256, 305,
#        186, 303, 217, 234, 177, 450, 448, 409, 185, 259, 311, 265, 204,
#        191, 288, 170, 219, 172, 300, 244, 198, 236, 311, 303, 179, 258,
#        424, 300, 267, 191, 185, 288, 435, 450, 445, 177, 260, 255, 304,
#        282, 447, 182, 452, 450, 450, 303, 428, 449, 267, 266, 454, 268,
#        261, 452, 303, 450, 188, 427, 245, 267, 444, 219, 219, 445, 262,
#        304, 267, 286, 312, 170, 246, 177, 289, 261, 270, 267, 208, 276,
#        424, 268, 301, 281, 189, 413, 185, 190, 207, 306, 187, 189, 312,
#        171, 298, 311, 172, 283, 312, 302, 444, 265, 283, 310, 178, 266,
#        303, 185, 400, 189, 252, 389, 411, 179, 196, 208, 179, 296, 284,
#        239, 190, 239, 305, 305, 457, 210, 302, 241, 254, 415, 250, 244,
#        300, 284, 302, 302, 286, 452, 245, 270, 266, 306, 276, 243, 289,
#        234, 182, 244, 232, 302, 179, 311, 233, 219, 455, 457, 313, 378,
#        204, 415, 213, 300, 303, 275, 305, 292, 268, 245, 389, 214, 215,
#        283, 181, 387, 264, 303, 457, 298, 269, 250, 266, 276, 307, 193,
#        166, 268, 212, 447, 281, 287, 446, 253, 173, 428, 232, 265, 258,
#        455, 209, 271, 440, 185, 430, 224, 285, 216, 245, 453, 430, 191,
#        283, 312, 410, 202, 276, 270, 299, 249, 171, 182, 258, 184, 182,
#        438], dtype=int64)

# %%
#total operations
u=0
for i in range(11191,0,-1):
    u=u+i
    #print(u,i)
    if i==1:
        print(u)
# Out:
# 62624836
